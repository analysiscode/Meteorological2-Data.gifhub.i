# %% [markdown]
# # Read the Data

# %%
import pandas as pd

# %%
weather=pd.read_csv('weatherHistory.csv')

# %%
weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
type(weather)
# Out:
# pandas.core.frame.DataFrame

# %%
weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# ...

# %%
weather.shape
# Out:
# (96453, 11)

# %%
weather.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# ...

# %%
weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Daily Summary'],
#       dtype='object')

# %%
#Check for missing values

# %%
weather.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
weather.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
from datetime import datetime
weather["Formatted Date"]=pd.to_datetime(weather["Formatted Date"],utc=True)

# %%
weather.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                    int64
# Visibility (km)                         float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
weather.set_index("Formatted Date").head()
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# ...

# %% [markdown]
# # Data Summarization method

# %%
weather.describe(include="all")
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5200/965645552.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   weather.describe(include="all")
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# count                       96453          96453       95936     96453.000000
# unique                      96429             27           2              NaN
# top     2010-08-01 22:00:00+00:00  Partly Cloudy        rain              NaN
# freq                            2          31733       85224              NaN
# first   2005-12-31 23:00:00+00:00            NaN         NaN              NaN
# last    2016-12-31 22:00:00+00:00            NaN         NaN              NaN
# mean                          NaN            NaN         NaN        11.932678
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1), object(3)
# memory usage: 8.1+ MB

# %%
weather.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Pressure (millibars)         4979
# Daily Summary                 214
# Temperature_New (C)             2
# Temperature_New2 (C)            2
# dtype: int64

# %%
weather["Summary"].value_counts().head()
# Out:
# Partly Cloudy    31733
# Mostly Cloudy    28094
# Overcast         16597
# Clear            10890
# Foggy             7148
# Name: Summary, dtype: int64

# %%
#count precipe type of wheather

# %%
weather["Precip Type"].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# # select/indexing

# %%
weather.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# ...

# %%
weather.iloc[0:5,0:4]
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556

# %%
weather.iloc[0:5,[0,3]]
# Out:
#              Formatted Date  Temperature (C)
# 0 2006-03-31 22:00:00+00:00         9.472222
# 1 2006-03-31 23:00:00+00:00         9.355556
# 2 2006-04-01 00:00:00+00:00         9.377778
# 3 2006-04-01 01:00:00+00:00         8.288889
# 4 2006-04-01 02:00:00+00:00         8.755556

# %%
weather.iloc[0:4]
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
# 2                     204          14.9569               1015.94
# ...

# %%
weather.iloc[:,0:3]
# Out:
#                  Formatted Date        Summary Precip Type
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain
# ...                         ...            ...         ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain
#
# [96453 rows x 3 columns]

# %%
weather.iloc[:,: -1]                                            #all the rows & column displayed escape last column
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
wh=weather.iloc[:,: -1] 
print(weather.shape)
wh.shape
# Out:
# (96453, 11)
# (96453, 10)

# %%
#label based indexing

# %%
weather.loc[0:4,["Summary","Precip Type"]]
# Out:
#          Summary Precip Type
# 0  Partly Cloudy        rain
# 1  Partly Cloudy        rain
# 2  Mostly Cloudy        rain
# 3  Partly Cloudy        rain
# 4  Mostly Cloudy        rain

# %%
a=weather.loc[0:5,"Summary"]
a
# Out:
# 0    Partly Cloudy
# 1    Partly Cloudy
# 2    Mostly Cloudy
# 3    Partly Cloudy
# 4    Mostly Cloudy
# 5    Partly Cloudy
# Name: Summary, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
weather[['Wind Bearing (degrees)']]
# Out:
#        Wind Bearing (degrees)
# 0                         251
# 1                         259
# 2                         204
# 3                         269
# 4                         259
# ...                       ...
# 96448                      31
# 96449                      20
# 96450                      30
# 96451                      20
# 96452                      39
#
# [96453 rows x 1 columns]

# %%
weather.loc[0:5,['Wind Bearing (degrees)']]
# Out:
#    Wind Bearing (degrees)
# 0                     251
# 1                     259
# 2                     204
# 3                     269
# 4                     259
# 5                     258

# %% [markdown]
# # FILTERING DATA

# %%
weather.loc[weather['Wind Speed (km/h)'] > 10,['Formatted Date','Wind Speed (km/h)']].head()
# Out:
#              Formatted Date  Wind Speed (km/h)
# 0 2006-03-31 22:00:00+00:00            14.1197
# 1 2006-03-31 23:00:00+00:00            14.2646
# 3 2006-04-01 01:00:00+00:00            14.1036
# 4 2006-04-01 02:00:00+00:00            11.0446
# 5 2006-04-01 03:00:00+00:00            13.9587

# %%
weather[weather["Wind Speed (km/h)"]<10].head()
# Out:
#               Formatted Date        Summary Precip Type  Temperature (C)  \
# 2  2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 18 2006-04-01 16:00:00+00:00  Mostly Cloudy        rain        14.255556
# 19 2006-04-01 17:00:00+00:00  Mostly Cloudy        rain        13.144444
# 20 2006-04-01 18:00:00+00:00  Mostly Cloudy        rain        11.550000
# 21 2006-04-01 19:00:00+00:00  Mostly Cloudy        rain        11.183333
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2                   9.377778      0.89             3.9284
# 18                 14.255556      0.69             8.5169
# 19                 13.144444      0.70             7.6314
# 20                 11.550000      0.77             7.3899
# 21                 11.183333      0.76             4.9266
#
#     Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 2                      204          14.9569               1015.94
# ...

# %%
#find out the temperature to rain
weather.loc[weather["Precip Type"]=="rain",["Temperature (C)"]].head()
# Out:
#    Temperature (C)
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556

# %%
weather["Summary"].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
weather[weather["Summary"].isin(["Windy","Breezy"])].tail(n=10)
# Out:
#                  Formatted Date Summary Precip Type  Temperature (C)  \
# 82401 2015-01-04 11:00:00+00:00   Windy        rain         5.000000
# 82403 2015-01-04 13:00:00+00:00   Windy        rain         5.000000
# 82404 2015-01-04 14:00:00+00:00  Breezy        rain         4.950000
# 82406 2015-01-04 16:00:00+00:00  Breezy        rain         3.838889
# 82409 2015-01-04 19:00:00+00:00  Breezy        rain         2.750000
# 82410 2015-01-04 20:00:00+00:00  Breezy        rain         2.172222
# 82412 2015-01-04 22:00:00+00:00  Breezy        rain         2.072222
# 82422 2015-01-05 08:00:00+00:00  Breezy        rain         1.111111
# 87082 2015-09-14 11:00:00+00:00  Breezy        rain        27.172222
# 89023 2016-08-05 08:00:00+00:00  Breezy        rain        27.777778
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 82401                 -0.727778      0.65            40.5398
# 82403                 -0.727778      0.65            40.5076
# ...

# %% [markdown]
# # Original data reset

# %%
w=weather.loc[(weather["Temperature (C)"]>10)& (weather["Summary"].isin(["Windy and Dry","Breezy and Dry"]))].head()
w.reset_index(inplace=True,drop=True)
w
# Out:
#              Formatted Date         Summary Precip Type  Temperature (C)  \
# 0 2012-04-29 10:00:00+00:00   Windy and Dry        rain        27.222222
# 1 2012-03-18 10:00:00+00:00  Breezy and Dry        rain        21.111111
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                 26.344444      0.24              40.25
# 1                 21.111111      0.26              33.81
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     150            9.982                1020.2
# 1                     240            9.982                1021.6
#
#                                        Daily Summary
# 0  Partly cloudy starting in the morning continui...
# 1           Partly cloudy starting in the afternoon.

# %% [markdown]
# # sorting

# %%
weather.sort_values(by=["Summary","Wind Bearing (degrees)"],ascending=[True,False]).tail()
# Out:
#                  Formatted Date                  Summary Precip Type  \
# 23047 2008-03-24 06:00:00+00:00  Windy and Partly Cloudy        rain
# 26818 2009-04-28 08:00:00+00:00  Windy and Partly Cloudy        rain
# 26819 2009-04-28 09:00:00+00:00  Windy and Partly Cloudy        rain
# 66719 2013-03-18 22:00:00+00:00  Windy and Partly Cloudy        rain
# 79567 2015-04-07 08:00:00+00:00  Windy and Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 23047         7.533333                  2.400000      0.69            45.0639
# 26818        18.888889                 18.888889      0.30            45.0800
# 26819        18.888889                 18.888889      0.33            40.2500
# 66719         4.466667                 -1.500000      0.82            41.4253
# 79567         7.827778                  3.050000      0.49            40.5559
#
#        Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# ...

# %% [markdown]
# # Conditional Adding column

# %%
import numpy as np
weather["Temperature_New (C)"]=np.where(weather["Temperature (C)"]>20,"Hot","Cold")
weather.tail(n=20)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 96433 2016-09-09 02:00:00+00:00          Clear        rain        15.011111
# 96434 2016-09-09 03:00:00+00:00          Clear        rain        15.016667
# 96435 2016-09-09 04:00:00+00:00          Clear        rain        13.872222
# 96436 2016-09-09 05:00:00+00:00          Clear        rain        16.072222
# 96437 2016-09-09 06:00:00+00:00  Partly Cloudy        rain        19.561111
# 96438 2016-09-09 07:00:00+00:00  Partly Cloudy        rain        22.138889
# 96439 2016-09-09 08:00:00+00:00  Partly Cloudy        rain        22.872222
# 96440 2016-09-09 09:00:00+00:00  Partly Cloudy        rain        27.072222
# 96441 2016-09-09 10:00:00+00:00  Partly Cloudy        rain        28.866667
# 96442 2016-09-09 11:00:00+00:00  Partly Cloudy        rain        30.994444
# 96443 2016-09-09 12:00:00+00:00  Partly Cloudy        rain        30.894444
# ...

# %%
weather["Temperature_New2 (C)"]=np.where(weather["Temperature (C)"]>10,"Hot",np.where(weather["Temperature_New (C)"]==10,"Partly cloudy","cold"))
weather.head(20)
# Out:
#               Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1  2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2  2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4  2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 03:00:00+00:00  Partly Cloudy        rain         9.222222
# 6  2006-04-01 04:00:00+00:00  Partly Cloudy        rain         7.733333
# 7  2006-04-01 05:00:00+00:00  Partly Cloudy        rain         8.772222
# 8  2006-04-01 06:00:00+00:00  Partly Cloudy        rain        10.822222
# 9  2006-04-01 07:00:00+00:00  Partly Cloudy        rain        13.772222
# 10 2006-04-01 08:00:00+00:00  Partly Cloudy        rain        16.016667
# 11 2006-04-01 09:00:00+00:00  Partly Cloudy        rain        17.144444
# ...

# %%
weather['Temperature_New (C)'].unique()
# Out:
# array(['Cold', 'Hot'], dtype=object)

# %%
weather.drop(['Temperature_New (C)'], axis = 1)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
weather['Temperature_New2 (C)'].unique()
# Out:
# array(['cold', 'Hot'], dtype=object)

# %%
weather.drop(['Temperature_New2 (C)'],axis=1)
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Pressure (millibars)         4979
# Daily Summary                 214
# Temperature_New (C)             2
# Temperature_New2 (C)            2
# dtype: int64

# %%
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# ...

# %%
weather.groupby("Precip Type").agg("mean")
# Out:
#              Temperature (C)  Apparent Temperature (C)  Humidity  \
# Precip Type
# rain               13.852989                 13.013425  0.718699
# snow               -3.270885                 -6.249847  0.863263
#
#              Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# Precip Type
# rain                 10.971219              189.123170        10.830711
# snow                  9.481998              174.754294         6.636570
#
#              Pressure (millibars)
# Precip Type
# rain                  1002.764548
# snow                  1006.216970

# %%
weather.groupby("Summary").agg(["mean","sum"])
# Out:
#                                     Temperature (C)                 \
#                                                mean            sum
# Summary
# Breezy                                     7.922016     427.788889
# Breezy and Dry                            21.111111      21.111111
# Breezy and Foggy                          -0.510317     -17.861111
# Breezy and Mostly Cloudy                  11.093411    5724.200000
# Breezy and Overcast                        7.241614    3823.572222
# Breezy and Partly Cloudy                  12.492761    4822.205556
# Clear                                     11.925109  129864.438889
# Dangerously Windy and Partly Cloudy        8.944444       8.944444
# Drizzle                                   10.847578     423.055556
# Dry                                       29.083660     988.844444
# Dry and Mostly Cloudy                     26.838492     375.738889
# Dry and Partly Cloudy                     26.605749    2288.094444
# ...

# %%
weather.groupby(["Apparent Temperature (C)","Humidity"]).agg(["mean","sum"])
# Out:
#                                   Temperature (C)             \
#                                              mean        sum
# Apparent Temperature (C) Humidity
# -27.716667               0.78          -20.000000 -20.000000
# -26.227778               0.82          -20.000000 -20.000000
# -25.922222               0.78          -20.555556 -20.555556
# -25.200000               0.78          -20.050000 -20.050000
# -25.072222               0.79          -20.277778 -20.277778
# ...                                           ...        ...
#  38.255556               0.31           37.072222  37.072222
#  38.377778               0.32           36.972222  36.972222
#  38.416667               0.27           37.872222  37.872222
#  38.661111               0.32           37.266667  37.266667
#  39.344444               0.47           34.955556  34.955556
#
#                                   Wind Speed (km/h)           \
#                                                mean      sum
# ...

# %% [markdown]
# # Data visualization

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # exploratory Analysis
# Univariate

# %% [markdown]
# # exploratory analysis

# %% [markdown]
# # Univariate

# %%
sns.distplot(weather["Apparent Temperature (C)"],kde=False)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Apparent Temperature (C)'>

# %%
plot=sns.countplot(x="Precip Type",data=weather)
plot.set_xticklabels(plot.get_xticklabels(),rotation=80)
# Out:
# [Text(0, 0, 'rain'), Text(1, 0, 'snow')]

# %% [markdown]
# # Bi-variate analysis
# Does the Humidity of the weather depend on the Apparent Temperature

# %%
sns.set_style("darkgrid")
sns.regplot(x="Apparent Temperature (C)", y="Humidity",data=weather)
plt.title("Relation between Apparent Temperature (C) and Humidity")
# save the figure
plt.savefig('plot1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#are outliners shewing the relationship

# %%
weather["Apparent Temperature (C)"].quantile([0.5,0.95,0.99])
weather_temp=weather.loc[weather["Apparent Temperature (C)"]<weather["Apparent Temperature (C)"].quantile(0.5)]

# %%
sns.regplot(x = "Apparent Temperature (C)",y="Humidity",data=weather_temp)
# Out:
# <AxesSubplot:xlabel='Apparent Temperature (C)', ylabel='Humidity'>

# %%
weather['Formatted Date'] = pd.to_datetime(weather['Formatted Date'], utc=True)
df_month =weather.set_index('Formatted Date')
df_month = df_month.resample('M').mean()

# %%
df_month.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00         0.577778                 -4.050000
# 2006-01-31 00:00:00+00:00        -1.677942                 -4.173708
# 2006-02-28 00:00:00+00:00        -0.065394                 -2.990716
# 2006-03-31 00:00:00+00:00         4.559274                  1.969780
# 2006-04-30 00:00:00+00:00        12.635031                 12.098827
#
#                            Humidity  Wind Speed (km/h)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00  0.890000          17.114300
# 2006-01-31 00:00:00+00:00  0.834610           8.894211
# 2006-02-28 00:00:00+00:00  0.843467          10.957008
# 2006-03-31 00:00:00+00:00  0.778737          14.421488
# 2006-04-30 00:00:00+00:00  0.728625          10.930670
#
#                            Wind Bearing (degrees)  Visibility (km)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00              140.000000         9.982000
# ...

# %%
sns.set_style("darkgrid")
sns.regplot(data=df_month, x="Apparent Temperature (C)", y="Humidity", color="g")
plt.title("Relation between Apparent Temperature (C) and Humidity")
# save the figure
plt.savefig('plot1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data = df_month)
plt.xlabel('Year')
plt.title("Variation of Apparent Temperature and Humidity with time")
# save the figure
plt.savefig('plot2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Pair plot for correlation of Apparent temperature & Humidity
sns.set_style("darkgrid")
plt.figure(figsize=(12,6))
plt.title("Correlation between Apparent temperature & Humidity")
sns.heatmap(data= df_month.corr(),annot=True)
# save the figure
plt.savefig('plot7.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.pairplot(df_month, kind='scatter')
# save the figure
plt.savefig('plot8.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.set_style("darkgrid")
sns.FacetGrid(weather, hue="Summary", height=10).map(plt.scatter, "Apparent Temperature (C)", "Humidity").add_legend()
plt.title("2D Scatter Plot with Color Coding for each Summary type")
# save the figure
plt.savefig('plot3.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# For Apparent Temperature (C)
sns.set_style("darkgrid")
sns.FacetGrid(weather, hue="Summary", height=10).map(sns.histplot, "Apparent Temperature (C)").add_legend()
plt.title("Analysis of Weather Conditions with Apparent Temperature")
# save the figure
plt.savefig('plot4.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# For Humidity
sns.set_style("darkgrid")
sns.FacetGrid(weather, hue="Summary",height=10).map(sns.histplot, "Humidity").add_legend()
plt.title("Analysis of Weather Conditions with Humidity")
# save the figure
plt.savefig('plot5.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Function for plotting Humidity & Apparent Temperature for all month
TEMP_DATA = df_month.iloc[:,0]
HUM_DATA = df_month.iloc[:,1]
def label_color(month):
    if month == 1:
        return 'January','blue'
    elif month == 2:
        return 'February','green'
    elif month == 3:
        return 'March','orange'
    elif month == 4:
        return 'April','yellow'
    elif month == 5:
        return 'May','red'
    elif month == 6:
        return 'June','violet'
    elif month == 7:
        return 'July','purple'
    elif month == 8: 
               return 'August','black'
    elif month == 9:
        return 'September','brown'
    elif month == 10:
        return 'October','darkblue'
    elif month == 11:
        return 'November','grey'
    else:
        return 'December','pink'
def plot_month(month, weather):
    label,color = label_color(month)
    mdata = weather[weather.index.month == month]
    sns.lineplot(data=mdata,label=label,color=color,marker='o')
    
def sns_plot(title,weather):
    plt.figure(figsize=(14,8))
    plt.title(title)
    plt.xlabel('YEAR')
    for i in range(1,13):
        plot_month(i,weather)
    plt.savefig('plot10.png', dpi=300, bbox_inches='tight') 
    #plt.savefig('plot11.png', dpi=300, bbox_inches='tight')  
    plt.show()

# %%
# Month-wise Plot for Apparent Temperature of 10 years 
title = 'Month-wise Plot for Apparent Temperature of 10 years' 
sns_plot(title,TEMP_DATA)

# %%
# Month-wise Plot for Humidity of 10 years 
title = 'Month-wise Plot for Humidity of 10 years' 
sns_plot(title, HUM_DATA)

# %%
# Function for plotting Apparent Temperature & Humidity for each month
def sns_month_plot(month):
    plt.figure(figsize=(15,10))
    label = label_color(month)[0]
    plt.title('Apparent Temperature Vs Humidity for {}'.format(label))
    plt.xlabel('YEAR')
    data = df_month[df_month.index.month == month]
    sns.lineplot(data=data, marker='o')
    name="month"+str(month)+".png"
    plt.savefig(name, dpi=300, bbox_inches='tight')  
    plt.show()
    print('-'*80)

# %%
# plot for the month of JANUARY - DECEMBER
for month in range(1,13):
    sns_month_plot(month)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
